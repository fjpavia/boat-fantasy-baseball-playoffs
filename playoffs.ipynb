# %% [markdown]
# # League 26714 — Playoffs
#
# Run the cell for each round. Edit the spreadsheet filename if yours differs.
# Each cell does everything: extract rosters, tally stats, score, publish.

# %% [markdown]
# ## Setup (run once per session)

# %%
# %cd /path/to/roto-playoffs   # <-- set this to your project folder
# !pip install -r requirements.txt

# %% [markdown]
# ## Seed the bracket (once, after final roto standings)
#
# Names must match your spreadsheet tab names exactly.

# %%
# !python run.py --seed "Seed 1 team" "Seed 2 team" "Seed 3 team" "Seed 4 team" "Seed 5 team" "Seed 6 team"

# %% [markdown]
# ## Round 1  (Aug 30 – Sep 5)
#
# Drop `--final` to post live mid-week standings; add it once Saturday's games are done.

# %%
# !python run.py week1.xlsx 1 --final --publish

# %% [markdown]
# ## Round 2  (Sep 6 – Sep 12)

# %%
# !python run.py week2.xlsx 2 --final --publish

# %% [markdown]
# ## Round 3 — Final  (Sep 13 – Sep 19)

# %%
# !python run.py week3.xlsx 3 --final --publish
